# %%
from bs4 import BeautifulSoup
import requests
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel("/content/Input.xlsx")

# %%
df.head()
# Out:
#             URL_ID                                                URL
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...

# %%
urls=df.URL

# %%
save_directory = '/content/drive/MyDrive/save_txt_files/'

def extract_article(url, article_id):
  web=requests.get(url)
  soup=BeautifulSoup(web.content,"html.parser")
  title=soup.title.text
  lines=soup.find_all("p")
  text=""
  for l in lines:
    text+=l.text+"\n"
  filename = f"{article_id}.txt"
  with open(filename, "w", encoding="utf-8") as file:
            file.write(title + "\n\n")
            file.write(text)
            print("done for id ",article_id)

# %%
for index, row in df.iterrows():
    url = row["URL"]
    article_id = row["URL_ID"]
    extract_article(url, article_id)
# Out:
# done for id  blackassign0001
# done for id  blackassign0002
# done for id  blackassign0003
# done for id  blackassign0004
# done for id  blackassign0005
# done for id  blackassign0006
# done for id  blackassign0007
# done for id  blackassign0008
# done for id  blackassign0009
# done for id  blackassign0010
# done for id  blackassign0011
# done for id  blackassign0012
# done for id  blackassign0013
# done for id  blackassign0014
# done for id  blackassign0015
# done for id  blackassign0016
# done for id  blackassign0017
# done for id  blackassign0018
# done for id  blackassign0019
# done for id  blackassign0020
# done for id  blackassign0021
# done for id  blackassign0022
# done for id  blackassign0023
# done for id  blackassign0024
# done for id  blackassign0025
# done for id  blackassign0026
# done for id  blackassign0027
# done for id  blackassign0028
# done for id  blackassign0029
# done for id  blackassign0030
# done for id  blackassign0031
# done for id  blackassign0032
# done for id  blackassign0033
# done for id  blackassign0034
# done for id  blackassign0035
# done for id  blackassign0036
# done for id  blackassign0037
# done for id  blackassign0038
# done for id  blackassign0039
# done for id  blackassign0040
# done for id  blackassign0041
# done for id  blackassign0042
# done for id  blackassign0043
# done for id  blackassign0044
# done for id  blackassign0045
# done for id  blackassign0046
# done for id  blackassign0047
# done for id  blackassign0048
# done for id  blackassign0049
# done for id  blackassign0050
# done for id  blackassign0051
# done for id  blackassign0052
# done for id  blackassign0053
# done for id  blackassign0054
# done for id  blackassign0055
# done for id  blackassign0056
# done for id  blackassign0057
# done for id  blackassign0058
# done for id  blackassign0059
# done for id  blackassign0060
# done for id  blackassign0061
# done for id  blackassign0062
# done for id  blackassign0063
# done for id  blackassign0064
# done for id  blackassign0065
# done for id  blackassign0066
# done for id  blackassign0067
# done for id  blackassign0068
# done for id  blackassign0069
# done for id  blackassign0070
# done for id  blackassign0071
# done for id  blackassign0072
# done for id  blackassign0073
# done for id  blackassign0074
# done for id  blackassign0075
# done for id  blackassign0076
# done for id  blackassign0077
# done for id  blackassign0078
# done for id  blackassign0079
# done for id  blackassign0080
# done for id  blackassign0081
# done for id  blackassign0082
# done for id  blackassign0083
# done for id  blackassign0084
# done for id  blackassign0085
# done for id  blackassign0086
# done for id  blackassign0087
# done for id  blackassign0088
# done for id  blackassign0089
# done for id  blackassign0090
# done for id  blackassign0091
# done for id  blackassign0092
# done for id  blackassign0093
# done for id  blackassign0094
# done for id  blackassign0095
# done for id  blackassign0096
# done for id  blackassign0097
# done for id  blackassign0098
# done for id  blackassign0099
# done for id  blackassign0100
